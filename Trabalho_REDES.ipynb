# %% [markdown]
# # Trabalho de Redes

# %% [markdown]
# ## Importando bibliotecas:

# %%
pip install sklearn.model
# Out:
# Requirement already satisfied: sklearn.model in /home/daniel23020/anaconda3/envs/ilumpy/lib/python3.11/site-packages (0.0.6)
# Requirement already satisfied: scikit-learn>=0.22 in /home/daniel23020/anaconda3/envs/ilumpy/lib/python3.11/site-packages (from sklearn.model) (1.4.1.post1)
# Requirement already satisfied: pandas in /home/daniel23020/anaconda3/envs/ilumpy/lib/python3.11/site-packages (from sklearn.model) (2.2.0)
# Requirement already satisfied: numpy<2.0,>=1.19.5 in /home/daniel23020/anaconda3/envs/ilumpy/lib/python3.11/site-packages (from scikit-learn>=0.22->sklearn.model) (1.24.3)
# Requirement already satisfied: scipy>=1.6.0 in /home/daniel23020/anaconda3/envs/ilumpy/lib/python3.11/site-packages (from scikit-learn>=0.22->sklearn.model) (1.12.0)
# Requirement already satisfied: joblib>=1.2.0 in /home/daniel23020/anaconda3/envs/ilumpy/lib/python3.11/site-packages (from scikit-learn>=0.22->sklearn.model) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/daniel23020/anaconda3/envs/ilumpy/lib/python3.11/site-packages (from scikit-learn>=0.22->sklearn.model) (3.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/daniel23020/anaconda3/envs/ilumpy/lib/python3.11/site-packages (from pandas->sklearn.model) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/daniel23020/anaconda3/envs/ilumpy/lib/python3.11/site-packages (from pandas->sklearn.model) (2022.7)
# Requirement already satisfied: tzdata>=2022.7 in /home/daniel23020/anaconda3/envs/ilumpy/lib/python3.11/site-packages (from pandas->sklearn.model) (2024.1)
# Requirement already satisfied: six>=1.5 in /home/daniel23020/anaconda3/envs/ilumpy/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->sklearn.model) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install torch
# Out:
# Requirement already satisfied: torch in /home/daniel23020/anaconda3/envs/ilumpy/lib/python3.11/site-packages (2.3.0)
# Requirement already satisfied: filelock in /home/daniel23020/anaconda3/envs/ilumpy/lib/python3.11/site-packages (from torch) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/daniel23020/anaconda3/envs/ilumpy/lib/python3.11/site-packages (from torch) (4.9.0)
# Requirement already satisfied: sympy in /home/daniel23020/anaconda3/envs/ilumpy/lib/python3.11/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /home/daniel23020/anaconda3/envs/ilumpy/lib/python3.11/site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /home/daniel23020/anaconda3/envs/ilumpy/lib/python3.11/site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in /home/daniel23020/anaconda3/envs/ilumpy/lib/python3.11/site-packages (from torch) (2024.3.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/daniel23020/anaconda3/envs/ilumpy/lib/python3.11/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/daniel23020/anaconda3/envs/ilumpy/lib/python3.11/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/daniel23020/anaconda3/envs/ilumpy/lib/python3.11/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/daniel23020/anaconda3/envs/ilumpy/lib/python3.11/site-packages (from torch) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/daniel23020/anaconda3/envs/ilumpy/lib/python3.11/site-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/daniel23020/anaconda3/envs/ilumpy/lib/python3.11/site-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/daniel23020/anaconda3/envs/ilumpy/lib/python3.11/site-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/daniel23020/anaconda3/envs/ilumpy/lib/python3.11/site-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/daniel23020/anaconda3/envs/ilumpy/lib/python3.11/site-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/daniel23020/anaconda3/envs/ilumpy/lib/python3.11/site-packages (from torch) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/daniel23020/anaconda3/envs/ilumpy/lib/python3.11/site-packages (from torch) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /home/daniel23020/anaconda3/envs/ilumpy/lib/python3.11/site-packages (from torch) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/daniel23020/anaconda3/envs/ilumpy/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.4.127)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/daniel23020/anaconda3/envs/ilumpy/lib/python3.11/site-packages (from jinja2->torch) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in /home/daniel23020/anaconda3/envs/ilumpy/lib/python3.11/site-packages (from sympy->torch) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install optuna
# Out:
# Requirement already satisfied: optuna in /home/daniel23020/anaconda3/envs/ilumpy/lib/python3.11/site-packages (3.5.0)
# Requirement already satisfied: alembic>=1.5.0 in /home/daniel23020/anaconda3/envs/ilumpy/lib/python3.11/site-packages (from optuna) (1.13.1)
# Requirement already satisfied: colorlog in /home/daniel23020/anaconda3/envs/ilumpy/lib/python3.11/site-packages (from optuna) (6.8.2)
# Requirement already satisfied: numpy in /home/daniel23020/anaconda3/envs/ilumpy/lib/python3.11/site-packages (from optuna) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /home/daniel23020/anaconda3/envs/ilumpy/lib/python3.11/site-packages (from optuna) (23.0)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /home/daniel23020/anaconda3/envs/ilumpy/lib/python3.11/site-packages (from optuna) (2.0.27)
# Requirement already satisfied: tqdm in /home/daniel23020/anaconda3/envs/ilumpy/lib/python3.11/site-packages (from optuna) (4.66.2)
# Requirement already satisfied: PyYAML in /home/daniel23020/anaconda3/envs/ilumpy/lib/python3.11/site-packages (from optuna) (6.0.1)
# Requirement already satisfied: Mako in /home/daniel23020/anaconda3/envs/ilumpy/lib/python3.11/site-packages (from alembic>=1.5.0->optuna) (1.3.2)
# Requirement already satisfied: typing-extensions>=4 in /home/daniel23020/anaconda3/envs/ilumpy/lib/python3.11/site-packages (from alembic>=1.5.0->optuna) (4.9.0)
# Requirement already satisfied: greenlet!=0.4.17 in /home/daniel23020/anaconda3/envs/ilumpy/lib/python3.11/site-packages (from sqlalchemy>=1.3.0->optuna) (3.0.3)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /home/daniel23020/anaconda3/envs/ilumpy/lib/python3.11/site-packages (from Mako->alembic>=1.5.0->optuna) (2.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd 
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import torch 
import torch.nn as nn 
import torch.optim as optim
import optuna
from tqdm import tqdm

# %% [markdown]
# ## REDE NEURAL

# %% [markdown]
# ### Importando o Dataset

# %%
df = pd.read_csv("tiktok_treated_data.csv")
df_trabalho = pd.DataFrame(df)

# %% [markdown]
# ### Separação dos dados:

# %%
df_trabalho.head(3)
# Out:
#      cosxt1    cosxt2    cosxt3    cosxt4    cosxt5    cosxt6    cosxt7  \
# 0 -1.230874 -0.453840  0.032798  0.017766  0.026197  0.043926  0.021420
# 1 -0.908985 -0.135402  0.250411 -0.343244 -0.572894  1.521106  0.815831
# 2 -1.341072 -0.467645 -0.117559  0.273214 -0.021553 -0.030836  0.197149
#
#      cosxt8    cosxt9   cosxt10  ...  video_duration_sec  verified_status  \
# 0 -0.177623  0.163330  0.350660  ...            0.983333                0
# 1  0.221128 -0.500735 -0.999268  ...            0.533333                0
# 2 -0.380195  0.297951 -0.174708  ...            0.516667                0
#
#    video_view_count  video_like_count  video_share_count  \
# 0          0.343359          0.029529           0.000941
# 1          0.140903          0.117591           0.074314
# 2          0.902350          0.148503           0.011158
#
#    video_download_count  video_comment_count  author_ban_status_active  \
# 0              0.000067             0.000000                       0.0
# 1              0.077431             0.071257                       1.0
# 2              0.055556             0.034274                       1.0
#
#    author_ban_status_banned  author_ban_status_under review
# 0                       0.0                             1.0
# 1                       0.0                             0.0
# 2                       0.0                             0.0
#
# [3 rows x 21 columns]

# %%
# Todos os atributos da nossa rede com excessão do atributo target.
FEATURES = ['cosxt1', 'cosxt2', 'cosxt3', 'cosxt4', 'cosxt5', 'cosxt6', 'cosxt7',
       'cosxt8', 'cosxt9', 'cosxt10', 'claim_status', 'video_duration_sec',
       'verified_status', 'video_like_count',
       'video_share_count', 'video_download_count', 'video_comment_count',
       'author_ban_status_active', 'author_ban_status_banned',
       'author_ban_status_under review']

# Target da nossa Rede, no caso um single target. 
TARGET = ['video_view_count']

df_trabalho = df_trabalho.reindex(FEATURES + TARGET, axis=1)

# %%
TAMANHO_TESTE = 0.15
TAMANHO_VALIDACAO = 0.10
SEMENTE_ALEATORIA = 61455

# Aqui fazemos a divisão entre treino e teste. 
indices = df_trabalho.index
indices_treino, indices_teste = train_test_split(
    indices, test_size=TAMANHO_TESTE, random_state=SEMENTE_ALEATORIA
)

# Aqui fazemos a divisão do treinamento em treino e validação
indices_treino, indices_validacao = train_test_split(
    indices_treino, test_size=TAMANHO_VALIDACAO, random_state=SEMENTE_ALEATORIA
)

# Definindo os três dataset. 
df_treino = df_trabalho.loc[indices_treino]
df_validacao = df_trabalho.loc[indices_validacao]
df_teste = df_trabalho.loc[indices_teste]

# Dividindo entre o target e as features de cada dataset
X_treino = df_treino.reindex(FEATURES, axis=1).values
y_treino = df_treino.reindex(TARGET, axis=1).values.ravel()


X_validacao = df_validacao.reindex(FEATURES, axis=1).values
y_validacao = df_validacao.reindex(TARGET, axis=1).values.ravel()


X_teste = df_teste.reindex(FEATURES, axis=1).values
y_teste = df_teste.reindex(TARGET, axis=1).values.ravel()


# Covertendo os dados para tensores do pytorch
X_treino = torch.tensor(X_treino, dtype=torch.float32)
y_treino = torch.tensor(y_treino, dtype=torch.float32)

X_validacao = torch.tensor(X_validacao, dtype=torch.float32)
y_validacao = torch.tensor(y_validacao, dtype=torch.float32)

X_teste = torch.tensor(X_teste, dtype=torch.float32)
y_teste = torch.tensor(y_teste, dtype=torch.float32)


# Alterando as dimensões do target 
y_treino = y_treino.view(-1,1)
y_validacao = y_validacao.view(-1,1)
y_teste = y_teste.view(-1,1)

# %% [markdown]
# ### Criando a Rede:

# %%
class view_predictor_MLP(nn.Module):
    def __init__(self, num_dados_entrada, estrutura, num_targets, funcao_ativacao, taxa_aprendizado, taxa_dropout):
        super(view_predictor_MLP, self).__init__()

        self.camadas =  nn.Sequential()
        
        # Definindo a função de ativação:
        if funcao_ativacao == "ReLU":
            self.ativacao = nn.ReLU()
        elif funcao_ativacao == "Sigmoid":
            self.ativacao = nn.Sigmoid()

        # Looping que adiciona as camadas dada uma lista, que contem o numero de camadas ocultas e neuronios. 
        for i in range(len(estrutura)):
            if i == 0:
                self.camadas.add_module('linear_{}'.format(i), nn.Linear(num_dados_entrada, estrutura[i]))
                self.camadas.add_module('sigmoid_{}'.format(i), self.ativacao)
            
            else:
                self.camadas.add_module('linear_{}'.format(i), nn.Linear(estrutura[i-1], estrutura[i]))
                self.camadas.add_module('sigmoid_{}'.format(i), self.ativacao)

        # adiciona a camadas final:
        self.camadas.add_module('linear_final', nn.Linear(estrutura[-1], num_targets))


        # Otimizador com Momento
        self.optimizer = optim.SGD(self.parameters(), lr=taxa_aprendizado)
        
        # Função de perda (Mean Squared Error)
        self.criterion = nn.MSELoss()

        # Define o Dropout
        self.dropout = nn.Dropout(p=taxa_dropout)
        
    def forward(self, x):

        # Condicional para quando estamos dentro do modo treinamento
        if self.training:
            for camada in self.camadas:
                
                 # Realiza o dropout na antes da aplicação da função linear, ou seja, antes de passar para a próxima camada a informação.
                if isinstance(camada, nn.Linear):
                    x = self.dropout(x)
                x = camada(x)

        # Se não estivermos no modo treinamento o dropout não é ativado. 
        else:
            for camada in self.camadas:
                x = camada(x)

        return x
    
    def treinamento(self, X_treino, y_treino, num_epocas):
        # Numero de treinamentos é definido pelo numero de epocas, ou seja, o numero de vezes que que nossa rede ve todos os dados de treino.
        
        for epoca in range(num_epocas):
            # Ativa o modo de treinamento
            self.train()
            
            # Realiza a propagação direta
            dados_de_saida = self(X_treino)
            
            # Calcula a perda:
            loss = self.criterion(dados_de_saida, y_treino)
            
            # Zera o gradiente:
            self.optimizer.zero_grad()

            # Realiza o Backpropagation:
            loss.backward()

            # Atualiza os parametros
            self.optimizer.step()
            

    def predicao(self, x):
        """
        Realiza a previsão a partir de um determinado conjunto de dados. 

        Args:
            X: Os dados do nosso dataset, varialvel no formato de tensor.

        Returns:
           retunr: Resultado das previsões com a rede, variável no formato de tensor. 
        """

        # Entra no modo previsão:
        self.eval()
        

        # Dertermina que não é mais necessario zerar o Gradiente.
        with torch.no_grad():
            dados_de_saida = self(x)
        

        return dados_de_saida

# %% [markdown]
# ### Treinando a Rede Neural:

# %% [markdown]
# #### Otimização pelo Optuna:

# %%
# Aplicando nossa Rede Neural no Optura afim de obter os melhores hiperparametros. 

# Definindo algumas informações que seram usadas posteriormente.
NUM_DADOS_DE_ENTRADA = 20
NUM_DADOS_DE_SAIDA = 1
EPOCAS = 1000

# Definindo o número de arquiteturas passíveis de serem testadas.
num_arquitetura = 500

# Função objetivo para otimização 
def objetivo(trial):

    # Definindo os hiperparâmetros a serem otimizados
    num_camadas = trial.suggest_int('num_camadas', 2, 15)

    ESTRUTURA_OCULTA = []
    for i in range(num_camadas):
        num_neuronios = trial.suggest_int(f'num_neuronios_camada:{i}', 2, 50)
        ESTRUTURA_OCULTA.append(num_neuronios)
    
    FUNCAO_ATIVACAO = trial.suggest_categorical('funcao_de_ativacao', ['ReLU', 'Sigmoid'])
    TAXA_DE_APRENDIZADO = trial.suggest_float('taxa_de_aprendizado', 1e-5, 1e-1, log=True)
    TAXA_DE_DROPOUT = trial.suggest_float('taxa_de_dropout', 0.0, 0.5)


    # Criando uma instância do modelo com os hiperparâmetros sugeridos
    modelo = view_predictor_MLP(NUM_DADOS_DE_ENTRADA, ESTRUTURA_OCULTA, NUM_DADOS_DE_SAIDA, FUNCAO_ATIVACAO, TAXA_DE_APRENDIZADO, TAXA_DE_DROPOUT)
    
    # Treinando o modelo
    modelo.treinamento(X_treino, y_treino, EPOCAS)
    
    # Fazendo previsões no conjunto de validação
    y_predito = modelo.predicao(X_validacao)

    # Calcula o MSE no conjunto de validação
    mse = mean_squared_error(y_validacao, y_predito)
    
    return mse


# Executando a otimização do Optuna
study = optuna.create_study(direction='minimize')

# Cria uma  barra de progresso com um total igual ao número de arquiteturas a serem testadas
with tqdm(total=num_arquitetura) as pbar:
    # Define da função de atualização da barra de progresso
    def update_progress_bar(study, trial):
        pbar.update(1)  # Atualiza a barra de progresso em uma unidade a cada chamada
    
    # Executa a otimização com Optuna
    study.optimize(objetivo, n_trials=num_arquitetura, callbacks=[update_progress_bar])


# Obtendo os melhores hiperparâmetros encontrados
parametros = study.best_params

# Apartir do numero de neuronios por camada podemos montar a variável, ESTRUTURA_OCULTA
neuronios_camada = []
for parametro in parametros:
    if parametro.startswith('num_neuronios'):
        neuronios_camada.append(parametros[parametro])
# Out:
# [I 2024-05-13 18:59:19,641] A new study created in memory with name: no-name-b5de9f9e-02dc-40d6-9308-67b9b0c22768
#   0%|          | 0/500 [00:00<?, ?it/s][I 2024-05-13 18:59:31,404] Trial 0 finished with value: 0.10496155917644501 and parameters: {'num_camadas': 7, 'num_neuronios_camada:0': 12, 'num_neuronios_camada:1': 5, 'num_neuronios_camada:2': 3, 'num_neuronios_camada:3': 45, 'num_neuronios_camada:4': 7, 'num_neuronios_camada:5': 22, 'num_neuronios_camada:6': 35, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.07331318920943145, 'taxa_de_dropout': 0.40713341968163785}. Best is trial 0 with value: 0.10496155917644501.
#   0%|          | 1/500 [00:11<1:37:49, 11.76s/it][I 2024-05-13 18:59:51,844] Trial 1 finished with value: 0.1049833595752716 and parameters: {'num_camadas': 10, 'num_neuronios_camada:0': 14, 'num_neuronios_camada:1': 29, 'num_neuronios_camada:2': 14, 'num_neuronios_camada:3': 36, 'num_neuronios_camada:4': 19, 'num_neuronios_camada:5': 35, 'num_neuronios_camada:6': 33, 'num_neuronios_camada:7': 32, 'num_neuronios_camada:8': 17, 'num_neuronios_camada:9': 36, 'funcao_de_ativacao': 'Sigmoid', 'taxa_de_aprendizado': 0.0004756307155500539, 'taxa_de_dropout': 0.35514397527033753}. Best is trial 0 with value: 0.10496155917644501.
#   0%|          | 2/500 [00:32<2:19:59, 16.87s/it][I 2024-05-13 19:00:24,374] Trial 2 finished with value: 0.10647063702344894 and parameters: {'num_camadas': 14, 'num_neuronios_camada:0': 17, 'num_neuronios_camada:1': 28, 'num_neuronios_camada:2': 13, 'num_neuronios_camada:3': 42, 'num_neuronios_camada:4': 13, 'num_neuronios_camada:5': 47, 'num_neuronios_camada:6': 42, 'num_neuronios_camada:7': 19, 'num_neuronios_camada:8': 24, 'num_neuronios_camada:9': 15, 'num_neuronios_camada:10': 27, 'num_neuronios_camada:11': 47, 'num_neuronios_camada:12': 36, 'num_neuronios_camada:13': 6, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.0005004888795675393, 'taxa_de_dropout': 0.4983951545665027}. Best is trial 0 with value: 0.10496155917644501.
#   1%|          | 3/500 [01:04<3:18:57, 24.02s/it][I 2024-05-13 19:00:40,956] Trial 3 finished with value: 0.10496728867292404 and parameters: {'num_camadas': 11, 'num_neuronios_camada:0': 47, 'num_neuronios_camada:1': 22, 'num_neuronios_camada:2': 15, 'num_neuronios_camada:3': 12, 'num_neuronios_camada:4': 4, 'num_neuronios_camada:5': 13, 'num_neuronios_camada:6': 5, 'num_neuronios_camada:7': 10, 'num_neuronios_camada:8': 30, 'num_neuronios_camada:9': 29, 'num_neuronios_camada:10': 5, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.033664443569765716, 'taxa_de_dropout': 0.1931562219472212}. Best is trial 0 with value: 0.10496155917644501.
#   1%|          | 4/500 [01:21<2:54:17, 21.08s/it][I 2024-05-13 19:00:59,047] Trial 4 finished with value: 0.10496485233306885 and parameters: {'num_camadas': 8, 'num_neuronios_camada:0': 32, 'num_neuronios_camada:1': 50, 'num_neuronios_camada:2': 30, 'num_neuronios_camada:3': 18, 'num_neuronios_camada:4': 49, 'num_neuronios_camada:5': 17, 'num_neuronios_camada:6': 34, 'num_neuronios_camada:7': 33, 'funcao_de_ativacao': 'Sigmoid', 'taxa_de_aprendizado': 0.0002576548726454286, 'taxa_de_dropout': 0.013013147955905913}. Best is trial 0 with value: 0.10496155917644501.
#   1%|          | 5/500 [01:39<2:45:01, 20.00s/it][I 2024-05-13 19:01:29,457] Trial 5 finished with value: 0.15051302313804626 and parameters: {'num_camadas': 12, 'num_neuronios_camada:0': 47, 'num_neuronios_camada:1': 48, 'num_neuronios_camada:2': 17, 'num_neuronios_camada:3': 22, 'num_neuronios_camada:4': 13, 'num_neuronios_camada:5': 46, 'num_neuronios_camada:6': 40, 'num_neuronios_camada:7': 28, 'num_neuronios_camada:8': 49, 'num_neuronios_camada:9': 43, 'num_neuronios_camada:10': 24, 'num_neuronios_camada:11': 24, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 3.0053919182696464e-05, 'taxa_de_dropout': 0.13391514198747234}. Best is trial 0 with value: 0.10496155917644501.
#   1%|          | 6/500 [02:09<3:13:49, 23.54s/it][I 2024-05-13 19:01:34,185] Trial 6 finished with value: 0.10507071763277054 and parameters: {'num_camadas': 3, 'num_neuronios_camada:0': 2, 'num_neuronios_camada:1': 34, 'num_neuronios_camada:2': 11, 'funcao_de_ativacao': 'Sigmoid', 'taxa_de_aprendizado': 0.000919993793657846, 'taxa_de_dropout': 0.4601806761105427}. Best is trial 0 with value: 0.10496155917644501.
#   1%|▏         | 7/500 [02:14<2:22:53, 17.39s/it][I 2024-05-13 19:01:42,293] Trial 7 finished with value: 0.10532522946596146 and parameters: {'num_camadas': 4, 'num_neuronios_camada:0': 21, 'num_neuronios_camada:1': 35, 'num_neuronios_camada:2': 10, 'num_neuronios_camada:3': 20, 'funcao_de_ativacao': 'Sigmoid', 'taxa_de_aprendizado': 1.309832187447052e-05, 'taxa_de_dropout': 0.48924106370645126}. Best is trial 0 with value: 0.10496155917644501.
#   2%|▏         | 8/500 [02:22<1:58:22, 14.44s/it][I 2024-05-13 19:02:20,323] Trial 8 finished with value: 0.10496730357408524 and parameters: {'num_camadas': 15, 'num_neuronios_camada:0': 37, 'num_neuronios_camada:1': 20, 'num_neuronios_camada:2': 13, 'num_neuronios_camada:3': 34, 'num_neuronios_camada:4': 6, 'num_neuronios_camada:5': 3, 'num_neuronios_camada:6': 35, 'num_neuronios_camada:7': 41, 'num_neuronios_camada:8': 41, 'num_neuronios_camada:9': 7, 'num_neuronios_camada:10': 47, 'num_neuronios_camada:11': 9, 'num_neuronios_camada:12': 49, 'num_neuronios_camada:13': 49, 'num_neuronios_camada:14': 40, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.0017137043564461332, 'taxa_de_dropout': 0.39600358046798334}. Best is trial 0 with value: 0.10496155917644501.
#   2%|▏         | 9/500 [03:00<2:58:29, 21.81s/it][I 2024-05-13 19:02:50,999] Trial 9 finished with value: 0.20444931089878082 and parameters: {'num_camadas': 11, 'num_neuronios_camada:0': 7, 'num_neuronios_camada:1': 35, 'num_neuronios_camada:2': 31, 'num_neuronios_camada:3': 35, 'num_neuronios_camada:4': 26, 'num_neuronios_camada:5': 46, 'num_neuronios_camada:6': 23, 'num_neuronios_camada:7': 35, 'num_neuronios_camada:8': 12, 'num_neuronios_camada:9': 36, 'num_neuronios_camada:10': 45, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 1.6158342449672643e-05, 'taxa_de_dropout': 0.2217968300641801}. Best is trial 0 with value: 0.10496155917644501.
#   2%|▏         | 10/500 [03:31<3:20:28, 24.55s/it][I 2024-05-13 19:03:07,637] Trial 10 finished with value: 0.10485764592885971 and parameters: {'num_camadas': 7, 'num_neuronios_camada:0': 27, 'num_neuronios_camada:1': 2, 'num_neuronios_camada:2': 50, 'num_neuronios_camada:3': 49, 'num_neuronios_camada:4': 40, 'num_neuronios_camada:5': 26, 'num_neuronios_camada:6': 19, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.05996572835264542, 'taxa_de_dropout': 0.320259796996583}. Best is trial 10 with value: 0.10485764592885971.
#   2%|▏         | 11/500 [03:47<3:00:20, 22.13s/it][I 2024-05-13 19:03:23,049] Trial 11 finished with value: 0.1049303263425827 and parameters: {'num_camadas': 6, 'num_neuronios_camada:0': 25, 'num_neuronios_camada:1': 2, 'num_neuronios_camada:2': 48, 'num_neuronios_camada:3': 46, 'num_neuronios_camada:4': 43, 'num_neuronios_camada:5': 28, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.08203517878800994, 'taxa_de_dropout': 0.3302903398389538}. Best is trial 10 with value: 0.10485764592885971.
#   2%|▏         | 12/500 [04:03<2:43:21, 20.08s/it][I 2024-05-13 19:03:36,480] Trial 12 finished with value: 0.10189628601074219 and parameters: {'num_camadas': 6, 'num_neuronios_camada:0': 28, 'num_neuronios_camada:1': 2, 'num_neuronios_camada:2': 50, 'num_neuronios_camada:3': 49, 'num_neuronios_camada:4': 44, 'num_neuronios_camada:5': 31, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.013694108160609, 'taxa_de_dropout': 0.3140366350365765}. Best is trial 12 with value: 0.10189628601074219.
#   3%|▎         | 13/500 [04:16<2:26:39, 18.07s/it][I 2024-05-13 19:03:50,173] Trial 13 finished with value: 0.10408412665128708 and parameters: {'num_camadas': 5, 'num_neuronios_camada:0': 33, 'num_neuronios_camada:1': 11, 'num_neuronios_camada:2': 50, 'num_neuronios_camada:3': 50, 'num_neuronios_camada:4': 37, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.008952135897827741, 'taxa_de_dropout': 0.2915554659806068}. Best is trial 12 with value: 0.10189628601074219.
#   3%|▎         | 14/500 [04:30<2:15:39, 16.75s/it][I 2024-05-13 19:04:01,828] Trial 14 finished with value: 0.10487590730190277 and parameters: {'num_camadas': 5, 'num_neuronios_camada:0': 37, 'num_neuronios_camada:1': 11, 'num_neuronios_camada:2': 42, 'num_neuronios_camada:3': 2, 'num_neuronios_camada:4': 38, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.007686975182346939, 'taxa_de_dropout': 0.29483136905174073}. Best is trial 12 with value: 0.10189628601074219.
#   3%|▎         | 15/500 [04:42<2:02:57, 15.21s/it][I 2024-05-13 19:04:06,494] Trial 15 finished with value: 0.05479305610060692 and parameters: {'num_camadas': 2, 'num_neuronios_camada:0': 39, 'num_neuronios_camada:1': 13, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.007712165306181316, 'taxa_de_dropout': 0.13352959789389754}. Best is trial 15 with value: 0.05479305610060692.
#   3%|▎         | 16/500 [04:46<1:37:06, 12.04s/it][I 2024-05-13 19:04:11,440] Trial 16 finished with value: 0.05259246006608009 and parameters: {'num_camadas': 2, 'num_neuronios_camada:0': 43, 'num_neuronios_camada:1': 12, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.007958988941937821, 'taxa_de_dropout': 0.10459989211511342}. Best is trial 16 with value: 0.05259246006608009.
#   3%|▎         | 17/500 [04:51<1:19:44,  9.91s/it][I 2024-05-13 19:04:16,734] Trial 17 finished with value: 0.05690772458910942 and parameters: {'num_camadas': 2, 'num_neuronios_camada:0': 41, 'num_neuronios_camada:1': 15, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.004127506108459652, 'taxa_de_dropout': 0.09071916641055887}. Best is trial 16 with value: 0.05259246006608009.
#   4%|▎         | 18/500 [04:57<1:08:26,  8.52s/it][I 2024-05-13 19:04:21,700] Trial 18 finished with value: 0.10564902424812317 and parameters: {'num_camadas': 2, 'num_neuronios_camada:0': 42, 'num_neuronios_camada:1': 16, 'funcao_de_ativacao': 'Sigmoid', 'taxa_de_aprendizado': 0.002334605391750321, 'taxa_de_dropout': 0.05588013032844491}. Best is trial 16 with value: 0.05259246006608009.
#   4%|▍         | 19/500 [05:02<59:44,  7.45s/it]  [I 2024-05-13 19:04:28,151] Trial 19 finished with value: 0.05129930377006531 and parameters: {'num_camadas': 3, 'num_neuronios_camada:0': 43, 'num_neuronios_camada:1': 8, 'num_neuronios_camada:2': 22, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.022035672383983435, 'taxa_de_dropout': 0.14916498994435726}. Best is trial 19 with value: 0.05129930377006531.
#   4%|▍         | 20/500 [05:08<57:12,  7.15s/it][I 2024-05-13 19:04:34,774] Trial 20 finished with value: 0.0687522143125534 and parameters: {'num_camadas': 4, 'num_neuronios_camada:0': 50, 'num_neuronios_camada:1': 8, 'num_neuronios_camada:2': 23, 'num_neuronios_camada:3': 2, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.024124836287793532, 'taxa_de_dropout': 0.17676075224267002}. Best is trial 19 with value: 0.05129930377006531.
#   4%|▍         | 21/500 [05:15<55:49,  6.99s/it][I 2024-05-13 19:04:39,580] Trial 21 finished with value: 0.060122519731521606 and parameters: {'num_camadas': 2, 'num_neuronios_camada:0': 42, 'num_neuronios_camada:1': 16, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.004235960171397057, 'taxa_de_dropout': 0.13593235128949227}. Best is trial 19 with value: 0.05129930377006531.
#   4%|▍         | 22/500 [05:19<50:28,  6.34s/it][I 2024-05-13 19:04:47,088] Trial 22 finished with value: 0.045027561485767365 and parameters: {'num_camadas': 3, 'num_neuronios_camada:0': 38, 'num_neuronios_camada:1': 9, 'num_neuronios_camada:2': 37, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.02063610870848695, 'taxa_de_dropout': 0.10296142166251293}. Best is trial 22 with value: 0.045027561485767365.
#   5%|▍         | 23/500 [05:27<53:10,  6.69s/it][I 2024-05-13 19:04:54,743] Trial 23 finished with value: 0.05208079144358635 and parameters: {'num_camadas': 4, 'num_neuronios_camada:0': 45, 'num_neuronios_camada:1': 8, 'num_neuronios_camada:2': 34, 'num_neuronios_camada:3': 11, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.01835874375746474, 'taxa_de_dropout': 0.08411128353138375}. Best is trial 22 with value: 0.045027561485767365.
#   5%|▍         | 24/500 [05:35<55:21,  6.98s/it][I 2024-05-13 19:05:04,657] Trial 24 finished with value: 0.04511319845914841 and parameters: {'num_camadas': 4, 'num_neuronios_camada:0': 46, 'num_neuronios_camada:1': 21, 'num_neuronios_camada:2': 38, 'num_neuronios_camada:3': 10, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.0271934779612613, 'taxa_de_dropout': 0.010600719013287657}. Best is trial 22 with value: 0.045027561485767365.
#   5%|▌         | 25/500 [05:45<1:02:13,  7.86s/it][I 2024-05-13 19:05:15,313] Trial 25 finished with value: 0.0362544059753418 and parameters: {'num_camadas': 4, 'num_neuronios_camada:0': 50, 'num_neuronios_camada:1': 21, 'num_neuronios_camada:2': 36, 'num_neuronios_camada:3': 27, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.038830480892202306, 'taxa_de_dropout': 0.010721500531585023}. Best is trial 25 with value: 0.0362544059753418.
#   5%|▌         | 26/500 [05:55<1:08:43,  8.70s/it][I 2024-05-13 19:05:28,703] Trial 26 finished with value: 0.10495653003454208 and parameters: {'num_camadas': 5, 'num_neuronios_camada:0': 48, 'num_neuronios_camada:1': 22, 'num_neuronios_camada:2': 39, 'num_neuronios_camada:3': 28, 'num_neuronios_camada:4': 30, 'funcao_de_ativacao': 'Sigmoid', 'taxa_de_aprendizado': 0.041833558206506756, 'taxa_de_dropout': 0.00562319769613627}. Best is trial 25 with value: 0.0362544059753418.
#   5%|▌         | 27/500 [06:09<1:19:40, 10.11s/it][I 2024-05-13 19:05:49,063] Trial 27 finished with value: 0.10496585071086884 and parameters: {'num_camadas': 9, 'num_neuronios_camada:0': 50, 'num_neuronios_camada:1': 25, 'num_neuronios_camada:2': 40, 'num_neuronios_camada:3': 29, 'num_neuronios_camada:4': 31, 'num_neuronios_camada:5': 5, 'num_neuronios_camada:6': 49, 'num_neuronios_camada:7': 3, 'num_neuronios_camada:8': 2, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.09156010469485075, 'taxa_de_dropout': 0.020515625406075155}. Best is trial 25 with value: 0.0362544059753418.
#   6%|▌         | 28/500 [06:29<1:43:42, 13.18s/it][I 2024-05-13 19:06:04,375] Trial 28 finished with value: 0.047849636524915695 and parameters: {'num_camadas': 6, 'num_neuronios_camada:0': 32, 'num_neuronios_camada:1': 42, 'num_neuronios_camada:2': 36, 'num_neuronios_camada:3': 11, 'num_neuronios_camada:4': 21, 'num_neuronios_camada:5': 38, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.04469211955519487, 'taxa_de_dropout': 0.05003963925974558}. Best is trial 25 with value: 0.0362544059753418.
#   6%|▌         | 29/500 [06:44<1:48:29, 13.82s/it][I 2024-05-13 19:06:21,389] Trial 29 finished with value: 0.11764483153820038 and parameters: {'num_camadas': 8, 'num_neuronios_camada:0': 36, 'num_neuronios_camada:1': 19, 'num_neuronios_camada:2': 44, 'num_neuronios_camada:3': 16, 'num_neuronios_camada:4': 50, 'num_neuronios_camada:5': 10, 'num_neuronios_camada:6': 6, 'num_neuronios_camada:7': 44, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.00010904894010969597, 'taxa_de_dropout': 0.0556388665483157}. Best is trial 25 with value: 0.0362544059753418.
#   6%|▌         | 30/500 [07:01<1:55:46, 14.78s/it][I 2024-05-13 19:06:28,172] Trial 30 finished with value: 0.05001131445169449 and parameters: {'num_camadas': 3, 'num_neuronios_camada:0': 45, 'num_neuronios_camada:1': 31, 'num_neuronios_camada:2': 28, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.013400640831020532, 'taxa_de_dropout': 0.046567217303874996}. Best is trial 25 with value: 0.0362544059753418.
#   6%|▌         | 31/500 [07:08<1:36:46, 12.38s/it][I 2024-05-13 19:06:43,529] Trial 31 finished with value: 0.10432013124227524 and parameters: {'num_camadas': 6, 'num_neuronios_camada:0': 30, 'num_neuronios_camada:1': 42, 'num_neuronios_camada:2': 36, 'num_neuronios_camada:3': 8, 'num_neuronios_camada:4': 22, 'num_neuronios_camada:5': 39, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.04026171271303117, 'taxa_de_dropout': 0.0423507991486633}. Best is trial 25 with value: 0.0362544059753418.
#   6%|▋         | 32/500 [07:23<1:43:31, 13.27s/it][I 2024-05-13 19:07:01,145] Trial 32 finished with value: 0.10492324829101562 and parameters: {'num_camadas': 7, 'num_neuronios_camada:0': 35, 'num_neuronios_camada:1': 42, 'num_neuronios_camada:2': 34, 'num_neuronios_camada:3': 24, 'num_neuronios_camada:4': 16, 'num_neuronios_camada:5': 40, 'num_neuronios_camada:6': 17, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.05016626828903995, 'taxa_de_dropout': 0.000846536063826597}. Best is trial 25 with value: 0.0362544059753418.
#   7%|▋         | 33/500 [07:41<1:53:27, 14.58s/it][I 2024-05-13 19:07:11,944] Trial 33 finished with value: 0.031787313520908356 and parameters: {'num_camadas': 4, 'num_neuronios_camada:0': 39, 'num_neuronios_camada:1': 26, 'num_neuronios_camada:2': 37, 'num_neuronios_camada:3': 6, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.09489167028536229, 'taxa_de_dropout': 0.08569473667810057}. Best is trial 33 with value: 0.031787313520908356.
#   7%|▋         | 34/500 [07:52<1:44:24, 13.44s/it][I 2024-05-13 19:07:23,416] Trial 34 finished with value: 0.03336627036333084 and parameters: {'num_camadas': 4, 'num_neuronios_camada:0': 39, 'num_neuronios_camada:1': 25, 'num_neuronios_camada:2': 45, 'num_neuronios_camada:3': 5, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.08186260360029844, 'taxa_de_dropout': 0.10173712764830553}. Best is trial 33 with value: 0.031787313520908356.
#   7%|▋         | 35/500 [08:03<1:39:36, 12.85s/it][I 2024-05-13 19:07:32,330] Trial 35 finished with value: 0.10490830987691879 and parameters: {'num_camadas': 3, 'num_neuronios_camada:0': 24, 'num_neuronios_camada:1': 26, 'num_neuronios_camada:2': 43, 'funcao_de_ativacao': 'Sigmoid', 'taxa_de_aprendizado': 0.08700846608081093, 'taxa_de_dropout': 0.23258493900750843}. Best is trial 33 with value: 0.031787313520908356.
#   7%|▋         | 36/500 [08:12<1:30:14, 11.67s/it][I 2024-05-13 19:07:44,977] Trial 36 finished with value: 0.03848704323172569 and parameters: {'num_camadas': 5, 'num_neuronios_camada:0': 38, 'num_neuronios_camada:1': 29, 'num_neuronios_camada:2': 46, 'num_neuronios_camada:3': 6, 'num_neuronios_camada:4': 34, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.05660447724353588, 'taxa_de_dropout': 0.10410690062668994}. Best is trial 33 with value: 0.031787313520908356.
#   7%|▋         | 37/500 [08:25<1:32:19, 11.96s/it][I 2024-05-13 19:07:55,562] Trial 37 finished with value: 0.04238635301589966 and parameters: {'num_camadas': 5, 'num_neuronios_camada:0': 19, 'num_neuronios_camada:1': 30, 'num_neuronios_camada:2': 45, 'num_neuronios_camada:3': 6, 'num_neuronios_camada:4': 33, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.09312424005293773, 'taxa_de_dropout': 0.1668868240318115}. Best is trial 33 with value: 0.031787313520908356.
#   8%|▊         | 38/500 [08:35<1:28:55, 11.55s/it][I 2024-05-13 19:08:13,140] Trial 38 finished with value: 0.10496488213539124 and parameters: {'num_camadas': 7, 'num_neuronios_camada:0': 40, 'num_neuronios_camada:1': 24, 'num_neuronios_camada:2': 46, 'num_neuronios_camada:3': 15, 'num_neuronios_camada:4': 35, 'num_neuronios_camada:5': 22, 'num_neuronios_camada:6': 13, 'funcao_de_ativacao': 'Sigmoid', 'taxa_de_aprendizado': 0.05615938396742194, 'taxa_de_dropout': 0.07790702222465432}. Best is trial 33 with value: 0.031787313520908356.
#   8%|▊         | 39/500 [08:53<1:42:38, 13.36s/it][I 2024-05-13 19:08:45,825] Trial 39 finished with value: 0.47643521428108215 and parameters: {'num_camadas': 13, 'num_neuronios_camada:0': 34, 'num_neuronios_camada:1': 28, 'num_neuronios_camada:2': 41, 'num_neuronios_camada:3': 5, 'num_neuronios_camada:4': 26, 'num_neuronios_camada:5': 50, 'num_neuronios_camada:6': 26, 'num_neuronios_camada:7': 19, 'num_neuronios_camada:8': 36, 'num_neuronios_camada:9': 49, 'num_neuronios_camada:10': 4, 'num_neuronios_camada:11': 50, 'num_neuronios_camada:12': 4, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.00010460693455560977, 'taxa_de_dropout': 0.1116936686881016}. Best is trial 33 with value: 0.031787313520908356.
#   8%|▊         | 40/500 [09:26<2:26:51, 19.16s/it][I 2024-05-13 19:08:54,746] Trial 40 finished with value: 0.10484113544225693 and parameters: {'num_camadas': 5, 'num_neuronios_camada:0': 31, 'num_neuronios_camada:1': 33, 'num_neuronios_camada:2': 3, 'num_neuronios_camada:3': 7, 'num_neuronios_camada:4': 27, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.014970816114557483, 'taxa_de_dropout': 0.20442238038006622}. Best is trial 33 with value: 0.031787313520908356.
#   8%|▊         | 41/500 [09:35<2:03:03, 16.09s/it][I 2024-05-13 19:09:02,047] Trial 41 finished with value: 0.03997401148080826 and parameters: {'num_camadas': 4, 'num_neuronios_camada:0': 17, 'num_neuronios_camada:1': 30, 'num_neuronios_camada:2': 46, 'num_neuronios_camada:3': 5, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.09425046599187928, 'taxa_de_dropout': 0.17631036716851659}. Best is trial 33 with value: 0.031787313520908356.
#   8%|▊         | 42/500 [09:42<1:42:40, 13.45s/it][I 2024-05-13 19:09:11,122] Trial 42 finished with value: 0.10132507234811783 and parameters: {'num_camadas': 4, 'num_neuronios_camada:0': 15, 'num_neuronios_camada:1': 38, 'num_neuronios_camada:2': 46, 'num_neuronios_camada:3': 4, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.035942129606040533, 'taxa_de_dropout': 0.26070975184503986}. Best is trial 33 with value: 0.031787313520908356.
#   9%|▊         | 43/500 [09:51<1:32:26, 12.14s/it][I 2024-05-13 19:09:19,610] Trial 43 finished with value: 0.03456427901983261 and parameters: {'num_camadas': 4, 'num_neuronios_camada:0': 11, 'num_neuronios_camada:1': 28, 'num_neuronios_camada:2': 47, 'num_neuronios_camada:3': 14, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.09971790143463534, 'taxa_de_dropout': 0.12639870195389885}. Best is trial 33 with value: 0.031787313520908356.
#   9%|▉         | 44/500 [09:59<1:23:55, 11.04s/it][I 2024-05-13 19:09:27,572] Trial 44 finished with value: 0.0368492566049099 and parameters: {'num_camadas': 3, 'num_neuronios_camada:0': 10, 'num_neuronios_camada:1': 23, 'num_neuronios_camada:2': 41, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.05839615319165957, 'taxa_de_dropout': 0.07490990796561815}. Best is trial 33 with value: 0.031787313520908356.
#   9%|▉         | 45/500 [10:07<1:16:43, 10.12s/it][I 2024-05-13 19:09:34,435] Trial 45 finished with value: 0.03138498216867447 and parameters: {'num_camadas': 3, 'num_neuronios_camada:0': 10, 'num_neuronios_camada:1': 23, 'num_neuronios_camada:2': 33, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.061483108364948996, 'taxa_de_dropout': 0.06813203705034078}. Best is trial 45 with value: 0.03138498216867447.
#   9%|▉         | 46/500 [10:14<1:09:10,  9.14s/it][I 2024-05-13 19:09:40,504] Trial 46 finished with value: 0.1049618124961853 and parameters: {'num_camadas': 4, 'num_neuronios_camada:0': 3, 'num_neuronios_camada:1': 19, 'num_neuronios_camada:2': 32, 'num_neuronios_camada:3': 13, 'funcao_de_ativacao': 'Sigmoid', 'taxa_de_aprendizado': 0.03131187214239209, 'taxa_de_dropout': 0.1352787049510562}. Best is trial 45 with value: 0.03138498216867447.
#   9%|▉         | 47/500 [10:20<1:02:03,  8.22s/it][I 2024-05-13 19:10:01,539] Trial 47 finished with value: 0.10496174544095993 and parameters: {'num_camadas': 9, 'num_neuronios_camada:0': 11, 'num_neuronios_camada:1': 26, 'num_neuronios_camada:2': 26, 'num_neuronios_camada:3': 30, 'num_neuronios_camada:4': 9, 'num_neuronios_camada:5': 10, 'num_neuronios_camada:6': 50, 'num_neuronios_camada:7': 49, 'num_neuronios_camada:8': 3, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.06460913427397703, 'taxa_de_dropout': 0.03162636937971666}. Best is trial 45 with value: 0.03138498216867447.
#  10%|▉         | 48/500 [10:41<1:30:53, 12.06s/it][I 2024-05-13 19:10:08,322] Trial 48 finished with value: 0.03962576389312744 and parameters: {'num_camadas': 3, 'num_neuronios_camada:0': 8, 'num_neuronios_camada:1': 27, 'num_neuronios_camada:2': 33, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.03468443626880364, 'taxa_de_dropout': 0.06400712690081332}. Best is trial 45 with value: 0.03138498216867447.
#  10%|▉         | 49/500 [10:48<1:18:46, 10.48s/it][I 2024-05-13 19:10:32,472] Trial 49 finished with value: 0.10704000294208527 and parameters: {'num_camadas': 11, 'num_neuronios_camada:0': 23, 'num_neuronios_camada:1': 18, 'num_neuronios_camada:2': 30, 'num_neuronios_camada:3': 24, 'num_neuronios_camada:4': 44, 'num_neuronios_camada:5': 19, 'num_neuronios_camada:6': 11, 'num_neuronios_camada:7': 18, 'num_neuronios_camada:8': 50, 'num_neuronios_camada:9': 18, 'num_neuronios_camada:10': 25, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.00030410482379958825, 'taxa_de_dropout': 0.11552989238850384}. Best is trial 45 with value: 0.03138498216867447.
#  10%|█         | 50/500 [11:12<1:49:21, 14.58s/it][I 2024-05-13 19:10:44,266] Trial 50 finished with value: 0.10493772476911545 and parameters: {'num_camadas': 6, 'num_neuronios_camada:0': 5, 'num_neuronios_camada:1': 33, 'num_neuronios_camada:2': 35, 'num_neuronios_camada:3': 20, 'num_neuronios_camada:4': 8, 'num_neuronios_camada:5': 31, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.010114030426137509, 'taxa_de_dropout': 0.4427230608621378}. Best is trial 45 with value: 0.03138498216867447.
#  10%|█         | 51/500 [11:24<1:42:51, 13.75s/it][I 2024-05-13 19:10:51,312] Trial 51 finished with value: 0.03125372156500816 and parameters: {'num_camadas': 3, 'num_neuronios_camada:0': 9, 'num_neuronios_camada:1': 24, 'num_neuronios_camada:2': 40, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.06057673382202016, 'taxa_de_dropout': 0.07814103377954915}. Best is trial 51 with value: 0.03125372156500816.
#  10%|█         | 52/500 [11:31<1:27:37, 11.74s/it][I 2024-05-13 19:10:57,391] Trial 52 finished with value: 0.03083648346364498 and parameters: {'num_camadas': 3, 'num_neuronios_camada:0': 13, 'num_neuronios_camada:1': 24, 'num_neuronios_camada:2': 39, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.06958333059962678, 'taxa_de_dropout': 0.027761097308687026}. Best is trial 52 with value: 0.03083648346364498.
#  11%|█         | 53/500 [11:37<1:14:47, 10.04s/it][I 2024-05-13 19:11:00,222] Trial 53 finished with value: 0.026540623977780342 and parameters: {'num_camadas': 2, 'num_neuronios_camada:0': 14, 'num_neuronios_camada:1': 24, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.06933266305452802, 'taxa_de_dropout': 0.027629326420501806}. Best is trial 53 with value: 0.026540623977780342.
#  11%|█         | 54/500 [11:40<58:32,  7.88s/it]  [I 2024-05-13 19:11:03,002] Trial 54 finished with value: 0.09241487830877304 and parameters: {'num_camadas': 2, 'num_neuronios_camada:0': 13, 'num_neuronios_camada:1': 24, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.0007603999555771142, 'taxa_de_dropout': 0.03169784263897306}. Best is trial 53 with value: 0.026540623977780342.
#  11%|█         | 55/500 [11:43<47:04,  6.35s/it][I 2024-05-13 19:11:07,058] Trial 55 finished with value: 0.03282171115279198 and parameters: {'num_camadas': 2, 'num_neuronios_camada:0': 9, 'num_neuronios_camada:1': 23, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.060308759799518136, 'taxa_de_dropout': 0.067940174539009}. Best is trial 53 with value: 0.026540623977780342.
#  11%|█         | 56/500 [11:47<41:53,  5.66s/it][I 2024-05-13 19:11:10,436] Trial 56 finished with value: 0.09558821469545364 and parameters: {'num_camadas': 2, 'num_neuronios_camada:0': 8, 'num_neuronios_camada:1': 23, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.0054338822896576365, 'taxa_de_dropout': 0.36711239481265534}. Best is trial 53 with value: 0.026540623977780342.
#  11%|█▏        | 57/500 [11:50<36:44,  4.98s/it][I 2024-05-13 19:11:14,779] Trial 57 finished with value: 0.10484890639781952 and parameters: {'num_camadas': 3, 'num_neuronios_camada:0': 16, 'num_neuronios_camada:1': 17, 'num_neuronios_camada:2': 26, 'funcao_de_ativacao': 'Sigmoid', 'taxa_de_aprendizado': 0.06474276241826536, 'taxa_de_dropout': 0.07484853126232983}. Best is trial 53 with value: 0.026540623977780342.
#  12%|█▏        | 58/500 [11:55<35:15,  4.79s/it][I 2024-05-13 19:11:17,775] Trial 58 finished with value: 0.033326614648103714 and parameters: {'num_camadas': 2, 'num_neuronios_camada:0': 6, 'num_neuronios_camada:1': 20, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.025430117481234277, 'taxa_de_dropout': 0.02853037763905213}. Best is trial 53 with value: 0.026540623977780342.
#  12%|█▏        | 59/500 [11:58<31:13,  4.25s/it][I 2024-05-13 19:11:20,624] Trial 59 finished with value: 0.08471307903528214 and parameters: {'num_camadas': 2, 'num_neuronios_camada:0': 13, 'num_neuronios_camada:1': 22, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.0021650577826482624, 'taxa_de_dropout': 0.15376037856732255}. Best is trial 53 with value: 0.026540623977780342.
#  12%|█▏        | 60/500 [12:00<28:04,  3.83s/it][I 2024-05-13 19:11:26,223] Trial 60 finished with value: 0.04379498213529587 and parameters: {'num_camadas': 3, 'num_neuronios_camada:0': 9, 'num_neuronios_camada:1': 32, 'num_neuronios_camada:2': 29, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.017595728305406847, 'taxa_de_dropout': 0.06694227173775584}. Best is trial 53 with value: 0.026540623977780342.
#  12%|█▏        | 61/500 [12:06<31:54,  4.36s/it][I 2024-05-13 19:11:28,794] Trial 61 finished with value: 0.03830459341406822 and parameters: {'num_camadas': 2, 'num_neuronios_camada:0': 4, 'num_neuronios_camada:1': 21, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.02335852869350297, 'taxa_de_dropout': 0.027078775499633126}. Best is trial 53 with value: 0.026540623977780342.
#  12%|█▏        | 62/500 [12:09<27:54,  3.82s/it][I 2024-05-13 19:11:31,417] Trial 62 finished with value: 0.029332581907510757 and parameters: {'num_camadas': 2, 'num_neuronios_camada:0': 6, 'num_neuronios_camada:1': 14, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.06725043655045487, 'taxa_de_dropout': 0.08941800709572162}. Best is trial 53 with value: 0.026540623977780342.
#  13%|█▎        | 63/500 [12:11<25:13,  3.46s/it][I 2024-05-13 19:11:36,325] Trial 63 finished with value: 0.03292319178581238 and parameters: {'num_camadas': 3, 'num_neuronios_camada:0': 6, 'num_neuronios_camada:1': 14, 'num_neuronios_camada:2': 38, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.06850110585204067, 'taxa_de_dropout': 0.08152505739820429}. Best is trial 53 with value: 0.026540623977780342.
#  13%|█▎        | 64/500 [12:16<28:18,  3.90s/it][I 2024-05-13 19:11:39,352] Trial 64 finished with value: 0.03753906115889549 and parameters: {'num_camadas': 2, 'num_neuronios_camada:0': 13, 'num_neuronios_camada:1': 25, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.04512974928788471, 'taxa_de_dropout': 0.09062476123252583}. Best is trial 53 with value: 0.026540623977780342.
#  13%|█▎        | 65/500 [12:19<26:21,  3.64s/it][I 2024-05-13 19:11:42,961] Trial 65 finished with value: 0.041872866451740265 and parameters: {'num_camadas': 3, 'num_neuronios_camada:0': 2, 'num_neuronios_camada:1': 17, 'num_neuronios_camada:2': 20, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.032019211670283015, 'taxa_de_dropout': 0.05762410907266492}. Best is trial 53 with value: 0.026540623977780342.
#  13%|█▎        | 66/500 [12:23<26:14,  3.63s/it][I 2024-05-13 19:11:45,266] Trial 66 finished with value: 0.0284231249243021 and parameters: {'num_camadas': 2, 'num_neuronios_camada:0': 19, 'num_neuronios_camada:1': 4, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.06949065172039397, 'taxa_de_dropout': 0.04122689659088012}. Best is trial 53 with value: 0.026540623977780342.
#  13%|█▎        | 67/500 [12:25<23:18,  3.23s/it][I 2024-05-13 19:11:49,342] Trial 67 finished with value: 0.028131697326898575 and parameters: {'num_camadas': 3, 'num_neuronios_camada:0': 18, 'num_neuronios_camada:1': 3, 'num_neuronios_camada:2': 32, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.07149505325147627, 'taxa_de_dropout': 0.04283793133426765}. Best is trial 53 with value: 0.026540623977780342.
#  14%|█▎        | 68/500 [12:29<25:05,  3.48s/it][I 2024-05-13 19:12:08,203] Trial 68 finished with value: 0.10496539622545242 and parameters: {'num_camadas': 15, 'num_neuronios_camada:0': 19, 'num_neuronios_camada:1': 5, 'num_neuronios_camada:2': 28, 'num_neuronios_camada:3': 41, 'num_neuronios_camada:4': 3, 'num_neuronios_camada:5': 7, 'num_neuronios_camada:6': 2, 'num_neuronios_camada:7': 5, 'num_neuronios_camada:8': 15, 'num_neuronios_camada:9': 2, 'num_neuronios_camada:10': 36, 'num_neuronios_camada:11': 3, 'num_neuronios_camada:12': 3, 'num_neuronios_camada:13': 34, 'num_neuronios_camada:14': 8, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.04862429207523468, 'taxa_de_dropout': 0.04188688383833883}. Best is trial 53 with value: 0.026540623977780342.
#  14%|█▍        | 69/500 [12:48<58:09,  8.10s/it][I 2024-05-13 19:12:12,290] Trial 69 finished with value: 0.06270056217908859 and parameters: {'num_camadas': 3, 'num_neuronios_camada:0': 21, 'num_neuronios_camada:1': 4, 'num_neuronios_camada:2': 24, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.012687948581578136, 'taxa_de_dropout': 0.020667838642251517}. Best is trial 53 with value: 0.026540623977780342.
#  14%|█▍        | 70/500 [12:52<49:24,  6.89s/it][I 2024-05-13 19:12:14,613] Trial 70 finished with value: 0.09292878210544586 and parameters: {'num_camadas': 2, 'num_neuronios_camada:0': 15, 'num_neuronios_camada:1': 5, 'funcao_de_ativacao': 'Sigmoid', 'taxa_de_aprendizado': 0.027887695735713813, 'taxa_de_dropout': 0.0017509735084851735}. Best is trial 53 with value: 0.026540623977780342.
#  14%|█▍        | 71/500 [12:54<39:29,  5.52s/it][I 2024-05-13 19:12:18,865] Trial 71 finished with value: 0.03838823363184929 and parameters: {'num_camadas': 3, 'num_neuronios_camada:0': 17, 'num_neuronios_camada:1': 3, 'num_neuronios_camada:2': 31, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.0699756134156802, 'taxa_de_dropout': 0.09185650608507027}. Best is trial 53 with value: 0.026540623977780342.
#  14%|█▍        | 72/500 [12:59<36:40,  5.14s/it][I 2024-05-13 19:12:24,404] Trial 72 finished with value: 0.040092598646879196 and parameters: {'num_camadas': 3, 'num_neuronios_camada:0': 20, 'num_neuronios_camada:1': 6, 'num_neuronios_camada:2': 39, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.07502266307487801, 'taxa_de_dropout': 0.041666688162052795}. Best is trial 53 with value: 0.026540623977780342.
#  15%|█▍        | 73/500 [13:04<37:26,  5.26s/it][I 2024-05-13 19:12:27,680] Trial 73 finished with value: 0.03784984350204468 and parameters: {'num_camadas': 2, 'num_neuronios_camada:0': 11, 'num_neuronios_camada:1': 9, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.03625675736577741, 'taxa_de_dropout': 0.05620492009170347}. Best is trial 53 with value: 0.026540623977780342.
#  15%|█▍        | 74/500 [13:08<33:07,  4.67s/it][I 2024-05-13 19:12:34,806] Trial 74 finished with value: 0.03834438696503639 and parameters: {'num_camadas': 4, 'num_neuronios_camada:0': 14, 'num_neuronios_camada:1': 12, 'num_neuronios_camada:2': 33, 'num_neuronios_camada:3': 39, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.09897351460483408, 'taxa_de_dropout': 0.04107710432095826}. Best is trial 53 with value: 0.026540623977780342.
#  15%|█▌        | 75/500 [13:15<38:16,  5.40s/it][I 2024-05-13 19:12:37,290] Trial 75 finished with value: 0.03173891454935074 and parameters: {'num_camadas': 2, 'num_neuronios_camada:0': 18, 'num_neuronios_camada:1': 7, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.04326377733368575, 'taxa_de_dropout': 0.01632712912916797}. Best is trial 53 with value: 0.026540623977780342.
#  15%|█▌        | 76/500 [13:17<31:59,  4.53s/it][I 2024-05-13 19:12:40,834] Trial 76 finished with value: 0.029949406161904335 and parameters: {'num_camadas': 2, 'num_neuronios_camada:0': 22, 'num_neuronios_camada:1': 10, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.04347700049822135, 'taxa_de_dropout': 0.016724306324275153}. Best is trial 53 with value: 0.026540623977780342.
#  15%|█▌        | 77/500 [13:21<29:50,  4.23s/it][I 2024-05-13 19:13:02,695] Trial 77 finished with value: 0.10496551543474197 and parameters: {'num_camadas': 12, 'num_neuronios_camada:0': 22, 'num_neuronios_camada:1': 11, 'num_neuronios_camada:2': 19, 'num_neuronios_camada:3': 32, 'num_neuronios_camada:4': 12, 'num_neuronios_camada:5': 15, 'num_neuronios_camada:6': 44, 'num_neuronios_camada:7': 12, 'num_neuronios_camada:8': 24, 'num_neuronios_camada:9': 23, 'num_neuronios_camada:10': 15, 'num_neuronios_camada:11': 31, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.020745060719592066, 'taxa_de_dropout': 0.01959151955159949}. Best is trial 53 with value: 0.026540623977780342.
#  16%|█▌        | 78/500 [13:43<1:06:57,  9.52s/it][I 2024-05-13 19:13:06,993] Trial 78 finished with value: 0.02733965963125229 and parameters: {'num_camadas': 2, 'num_neuronios_camada:0': 27, 'num_neuronios_camada:1': 10, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.05070674465649901, 'taxa_de_dropout': 0.00019912536277282705}. Best is trial 53 with value: 0.026540623977780342.
#  16%|█▌        | 79/500 [13:47<55:48,  7.95s/it]  [I 2024-05-13 19:13:11,000] Trial 79 finished with value: 0.028985807672142982 and parameters: {'num_camadas': 2, 'num_neuronios_camada:0': 26, 'num_neuronios_camada:1': 10, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.04837167348524294, 'taxa_de_dropout': 0.001560953376518591}. Best is trial 53 with value: 0.026540623977780342.
#  16%|█▌        | 80/500 [13:51<47:23,  6.77s/it][I 2024-05-13 19:13:15,013] Trial 80 finished with value: 0.137990340590477 and parameters: {'num_camadas': 2, 'num_neuronios_camada:0': 26, 'num_neuronios_camada:1': 10, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 5.865311724081548e-05, 'taxa_de_dropout': 0.0010963134856389473}. Best is trial 53 with value: 0.026540623977780342.
#  16%|█▌        | 81/500 [13:55<41:30,  5.94s/it][I 2024-05-13 19:13:18,150] Trial 81 finished with value: 0.030281709507107735 and parameters: {'num_camadas': 2, 'num_neuronios_camada:0': 29, 'num_neuronios_camada:1': 13, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.04535426898378447, 'taxa_de_dropout': 0.03246229206310694}. Best is trial 53 with value: 0.026540623977780342.
#  16%|█▋        | 82/500 [13:58<35:32,  5.10s/it][I 2024-05-13 19:13:21,062] Trial 82 finished with value: 0.04045126587152481 and parameters: {'num_camadas': 2, 'num_neuronios_camada:0': 28, 'num_neuronios_camada:1': 14, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.028164350780470915, 'taxa_de_dropout': 0.014196179630904486}. Best is trial 53 with value: 0.026540623977780342.
#  17%|█▋        | 83/500 [14:01<30:53,  4.44s/it][I 2024-05-13 19:13:24,209] Trial 83 finished with value: 0.031063133850693703 and parameters: {'num_camadas': 2, 'num_neuronios_camada:0': 29, 'num_neuronios_camada:1': 13, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.04912830014408824, 'taxa_de_dropout': 0.037351647325761475}. Best is trial 53 with value: 0.026540623977780342.
#  17%|█▋        | 84/500 [14:04<28:06,  4.06s/it][I 2024-05-13 19:13:27,877] Trial 84 finished with value: 0.026579342782497406 and parameters: {'num_camadas': 2, 'num_neuronios_camada:0': 25, 'num_neuronios_camada:1': 7, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.07653917458551619, 'taxa_de_dropout': 0.011877259070172971}. Best is trial 53 with value: 0.026540623977780342.
#  17%|█▋        | 85/500 [14:08<27:14,  3.94s/it][I 2024-05-13 19:13:30,970] Trial 85 finished with value: 0.028789954259991646 and parameters: {'num_camadas': 2, 'num_neuronios_camada:0': 24, 'num_neuronios_camada:1': 7, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.04666563288850589, 'taxa_de_dropout': 0.013040912641327704}. Best is trial 53 with value: 0.026540623977780342.
#  17%|█▋        | 86/500 [14:11<25:25,  3.69s/it][I 2024-05-13 19:13:33,957] Trial 86 finished with value: 0.028803840279579163 and parameters: {'num_camadas': 2, 'num_neuronios_camada:0': 25, 'num_neuronios_camada:1': 2, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.07651974520127995, 'taxa_de_dropout': 0.012302623095705765}. Best is trial 53 with value: 0.026540623977780342.
#  17%|█▋        | 87/500 [14:14<23:55,  3.48s/it][I 2024-05-13 19:13:37,100] Trial 87 finished with value: 0.06767496466636658 and parameters: {'num_camadas': 2, 'num_neuronios_camada:0': 26, 'num_neuronios_camada:1': 2, 'funcao_de_ativacao': 'Sigmoid', 'taxa_de_aprendizado': 0.08034251902811072, 'taxa_de_dropout': 0.047601176645106116}. Best is trial 53 with value: 0.026540623977780342.
#  18%|█▊        | 88/500 [14:17<23:10,  3.38s/it][I 2024-05-13 19:13:41,861] Trial 88 finished with value: 0.026373855769634247 and parameters: {'num_camadas': 3, 'num_neuronios_camada:0': 25, 'num_neuronios_camada:1': 7, 'num_neuronios_camada:2': 9, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.07795853319362658, 'taxa_de_dropout': 0.007911875212086287}. Best is trial 88 with value: 0.026373855769634247.
#  18%|█▊        | 89/500 [14:22<25:58,  3.79s/it][I 2024-05-13 19:13:46,156] Trial 89 finished with value: 0.04188602790236473 and parameters: {'num_camadas': 3, 'num_neuronios_camada:0': 24, 'num_neuronios_camada:1': 7, 'num_neuronios_camada:2': 10, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.01625864755119106, 'taxa_de_dropout': 0.009219448289168852}. Best is trial 88 with value: 0.026373855769634247.
#  18%|█▊        | 90/500 [14:26<26:56,  3.94s/it][I 2024-05-13 19:13:49,961] Trial 90 finished with value: 0.04348911717534065 and parameters: {'num_camadas': 3, 'num_neuronios_camada:0': 25, 'num_neuronios_camada:1': 4, 'num_neuronios_camada:2': 6, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.036232552246594316, 'taxa_de_dropout': 0.0038718030317651062}. Best is trial 88 with value: 0.026373855769634247.
#  18%|█▊        | 91/500 [14:30<26:35,  3.90s/it][I 2024-05-13 19:13:53,959] Trial 91 finished with value: 0.028356356546282768 and parameters: {'num_camadas': 2, 'num_neuronios_camada:0': 27, 'num_neuronios_camada:1': 7, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.07482391224646925, 'taxa_de_dropout': 0.019933727598896882}. Best is trial 88 with value: 0.026373855769634247.
#  18%|█▊        | 92/500 [14:34<26:43,  3.93s/it][I 2024-05-13 19:13:57,768] Trial 92 finished with value: 0.02746642380952835 and parameters: {'num_camadas': 2, 'num_neuronios_camada:0': 27, 'num_neuronios_camada:1': 6, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.07614473361322295, 'taxa_de_dropout': 0.020552765308873733}. Best is trial 88 with value: 0.026373855769634247.
#  19%|█▊        | 93/500 [14:38<26:24,  3.89s/it][I 2024-05-13 19:14:01,574] Trial 93 finished with value: 0.02792525477707386 and parameters: {'num_camadas': 2, 'num_neuronios_camada:0': 27, 'num_neuronios_camada:1': 6, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.07871974993437462, 'taxa_de_dropout': 0.05151993198714399}. Best is trial 88 with value: 0.026373855769634247.
#  19%|█▉        | 94/500 [14:41<26:10,  3.87s/it][I 2024-05-13 19:14:06,692] Trial 94 finished with value: 0.02908768132328987 and parameters: {'num_camadas': 3, 'num_neuronios_camada:0': 27, 'num_neuronios_camada:1': 7, 'num_neuronios_camada:2': 16, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.08543966357413207, 'taxa_de_dropout': 0.046998829894881175}. Best is trial 88 with value: 0.026373855769634247.
#  19%|█▉        | 95/500 [14:47<28:38,  4.24s/it][I 2024-05-13 19:14:10,047] Trial 95 finished with value: 0.03627493977546692 and parameters: {'num_camadas': 2, 'num_neuronios_camada:0': 31, 'num_neuronios_camada:1': 6, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.05662881366163576, 'taxa_de_dropout': 0.025232110870180763}. Best is trial 88 with value: 0.026373855769634247.
#  19%|█▉        | 96/500 [14:50<26:46,  3.98s/it][I 2024-05-13 19:14:13,755] Trial 96 finished with value: 0.03482227027416229 and parameters: {'num_camadas': 3, 'num_neuronios_camada:0': 23, 'num_neuronios_camada:1': 4, 'num_neuronios_camada:2': 12, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.05342351749072101, 'taxa_de_dropout': 0.05785525014943948}. Best is trial 88 with value: 0.026373855769634247.
#  19%|█▉        | 97/500 [14:54<26:10,  3.90s/it][I 2024-05-13 19:14:22,354] Trial 97 finished with value: 0.03191548213362694 and parameters: {'num_camadas': 4, 'num_neuronios_camada:0': 27, 'num_neuronios_camada:1': 8, 'num_neuronios_camada:2': 9, 'num_neuronios_camada:3': 42, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.09789817719927266, 'taxa_de_dropout': 0.035162884464197096}. Best is trial 88 with value: 0.026373855769634247.
#  20%|█▉        | 98/500 [15:02<35:33,  5.31s/it][I 2024-05-13 19:14:25,075] Trial 98 finished with value: 0.039396531879901886 and parameters: {'num_camadas': 2, 'num_neuronios_camada:0': 28, 'num_neuronios_camada:1': 6, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.07679436226978226, 'taxa_de_dropout': 0.050732429449113915}. Best is trial 88 with value: 0.026373855769634247.
#  20%|█▉        | 99/500 [15:05<30:17,  4.53s/it][I 2024-05-13 19:14:28,145] Trial 99 finished with value: 0.10777975618839264 and parameters: {'num_camadas': 3, 'num_neuronios_camada:0': 24, 'num_neuronios_camada:1': 3, 'num_neuronios_camada:2': 2, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.0011960542356653885, 'taxa_de_dropout': 0.019940436107844968}. Best is trial 88 with value: 0.026373855769634247.
#  20%|██        | 100/500 [15:08<27:17,  4.09s/it][I 2024-05-13 19:14:31,573] Trial 100 finished with value: 0.10369467735290527 and parameters: {'num_camadas': 2, 'num_neuronios_camada:0': 33, 'num_neuronios_camada:1': 9, 'funcao_de_ativacao': 'Sigmoid', 'taxa_de_aprendizado': 0.037614647031747314, 'taxa_de_dropout': 0.2625148514722593}. Best is trial 88 with value: 0.026373855769634247.
#  20%|██        | 101/500 [15:11<25:53,  3.89s/it][I 2024-05-13 19:14:34,554] Trial 101 finished with value: 0.027012677863240242 and parameters: {'num_camadas': 2, 'num_neuronios_camada:0': 25, 'num_neuronios_camada:1': 2, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.08002620329934325, 'taxa_de_dropout': 0.013215913375560596}. Best is trial 88 with value: 0.026373855769634247.
#  20%|██        | 102/500 [15:14<24:00,  3.62s/it][I 2024-05-13 19:14:37,409] Trial 102 finished with value: 0.04148011654615402 and parameters: {'num_camadas': 2, 'num_neuronios_camada:0': 30, 'num_neuronios_camada:1': 3, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.08002490421897145, 'taxa_de_dropout': 0.027946151635013995}. Best is trial 88 with value: 0.026373855769634247.
#  21%|██        | 103/500 [15:17<22:25,  3.39s/it][I 2024-05-13 19:15:06,653] Trial 103 finished with value: 0.1049661934375763 and parameters: {'num_camadas': 14, 'num_neuronios_camada:0': 21, 'num_neuronios_camada:1': 5, 'num_neuronios_camada:2': 6, 'num_neuronios_camada:3': 46, 'num_neuronios_camada:4': 19, 'num_neuronios_camada:5': 42, 'num_neuronios_camada:6': 28, 'num_neuronios_camada:7': 50, 'num_neuronios_camada:8': 41, 'num_neuronios_camada:9': 13, 'num_neuronios_camada:10': 36, 'num_neuronios_camada:11': 21, 'num_neuronios_camada:12': 20, 'num_neuronios_camada:13': 3, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.054229629490252014, 'taxa_de_dropout': 0.01340879839026514}. Best is trial 88 with value: 0.026373855769634247.
# ...
#  93%|█████████▎| 465/500 [1:01:00<04:15,  7.31s/it][I 2024-05-13 20:00:31,978] Trial 465 finished with value: 0.1049647256731987 and parameters: {'num_camadas': 4, 'num_neuronios_camada:0': 29, 'num_neuronios_camada:1': 31, 'num_neuronios_camada:2': 42, 'num_neuronios_camada:3': 27, 'funcao_de_ativacao': 'Sigmoid', 'taxa_de_aprendizado': 0.08388523594586368, 'taxa_de_dropout': 0.2393565439090613}. Best is trial 274 with value: 0.02556474693119526.
#  93%|█████████▎| 466/500 [1:01:12<04:50,  8.53s/it][I 2024-05-13 20:00:38,169] Trial 466 finished with value: 0.030287250876426697 and parameters: {'num_camadas': 3, 'num_neuronios_camada:0': 31, 'num_neuronios_camada:1': 30, 'num_neuronios_camada:2': 23, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.06354328451191661, 'taxa_de_dropout': 0.03182589382030492}. Best is trial 274 with value: 0.02556474693119526.
#  93%|█████████▎| 467/500 [1:01:18<04:18,  7.83s/it][I 2024-05-13 20:00:42,510] Trial 467 finished with value: 0.11306656897068024 and parameters: {'num_camadas': 3, 'num_neuronios_camada:0': 33, 'num_neuronios_camada:1': 4, 'num_neuronios_camada:2': 22, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.00016947599645470072, 'taxa_de_dropout': 0.01730177650332272}. Best is trial 274 with value: 0.02556474693119526.
#  94%|█████████▎| 468/500 [1:01:22<03:37,  6.78s/it][I 2024-05-13 20:00:54,012] Trial 468 finished with value: 0.0267453845590353 and parameters: {'num_camadas': 4, 'num_neuronios_camada:0': 38, 'num_neuronios_camada:1': 34, 'num_neuronios_camada:2': 25, 'num_neuronios_camada:3': 33, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.09971079480595774, 'taxa_de_dropout': 0.0077194618312950375}. Best is trial 274 with value: 0.02556474693119526.
#  94%|█████████▍| 469/500 [1:01:34<04:14,  8.20s/it][I 2024-05-13 20:01:01,334] Trial 469 finished with value: 0.02765955589711666 and parameters: {'num_camadas': 3, 'num_neuronios_camada:0': 35, 'num_neuronios_camada:1': 31, 'num_neuronios_camada:2': 21, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.09981642706868234, 'taxa_de_dropout': 0.023621402134121568}. Best is trial 274 with value: 0.02556474693119526.
#  94%|█████████▍| 470/500 [1:01:41<03:58,  7.94s/it][I 2024-05-13 20:01:05,817] Trial 470 finished with value: 0.028876036405563354 and parameters: {'num_camadas': 3, 'num_neuronios_camada:0': 32, 'num_neuronios_camada:1': 32, 'num_neuronios_camada:2': 24, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.0751105073205183, 'taxa_de_dropout': 0.04134709668164482}. Best is trial 274 with value: 0.02556474693119526.
#  94%|█████████▍| 471/500 [1:01:46<03:20,  6.90s/it][I 2024-05-13 20:01:13,550] Trial 471 finished with value: 0.026377670466899872 and parameters: {'num_camadas': 4, 'num_neuronios_camada:0': 29, 'num_neuronios_camada:1': 3, 'num_neuronios_camada:2': 19, 'num_neuronios_camada:3': 41, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.083944118307599, 'taxa_de_dropout': 0.0005058302039835805}. Best is trial 274 with value: 0.02556474693119526.
#  94%|█████████▍| 472/500 [1:01:53<03:20,  7.15s/it][I 2024-05-13 20:01:25,733] Trial 472 finished with value: 0.06263086199760437 and parameters: {'num_camadas': 5, 'num_neuronios_camada:0': 30, 'num_neuronios_camada:1': 29, 'num_neuronios_camada:2': 25, 'num_neuronios_camada:3': 49, 'num_neuronios_camada:4': 10, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.04624800704014141, 'taxa_de_dropout': 0.359703029282412}. Best is trial 274 with value: 0.02556474693119526.
#  95%|█████████▍| 473/500 [1:02:06<03:53,  8.66s/it][I 2024-05-13 20:01:32,867] Trial 473 finished with value: 0.02722797356545925 and parameters: {'num_camadas': 3, 'num_neuronios_camada:0': 34, 'num_neuronios_camada:1': 36, 'num_neuronios_camada:2': 22, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.07036819943397432, 'taxa_de_dropout': 0.014810564417583978}. Best is trial 274 with value: 0.02556474693119526.
#  95%|█████████▍| 474/500 [1:02:13<03:33,  8.20s/it][I 2024-05-13 20:01:38,070] Trial 474 finished with value: 0.02664843201637268 and parameters: {'num_camadas': 3, 'num_neuronios_camada:0': 26, 'num_neuronios_camada:1': 5, 'num_neuronios_camada:2': 24, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.0828353817505353, 'taxa_de_dropout': 9.317015033075485e-06}. Best is trial 274 with value: 0.02556474693119526.
#  95%|█████████▌| 475/500 [1:02:18<03:02,  7.30s/it][I 2024-05-13 20:01:44,870] Trial 475 finished with value: 0.04198445379734039 and parameters: {'num_camadas': 3, 'num_neuronios_camada:0': 37, 'num_neuronios_camada:1': 30, 'num_neuronios_camada:2': 16, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.05879230399324277, 'taxa_de_dropout': 0.25474324677563087}. Best is trial 274 with value: 0.02556474693119526.
#  95%|█████████▌| 476/500 [1:02:25<02:51,  7.15s/it][I 2024-05-13 20:01:51,976] Trial 476 finished with value: 0.029253670945763588 and parameters: {'num_camadas': 4, 'num_neuronios_camada:0': 28, 'num_neuronios_camada:1': 2, 'num_neuronios_camada:2': 20, 'num_neuronios_camada:3': 44, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.09970913504838164, 'taxa_de_dropout': 0.0242091626647487}. Best is trial 274 with value: 0.02556474693119526.
#  95%|█████████▌| 477/500 [1:02:32<02:44,  7.14s/it][I 2024-05-13 20:01:58,026] Trial 477 finished with value: 0.026674803346395493 and parameters: {'num_camadas': 3, 'num_neuronios_camada:0': 32, 'num_neuronios_camada:1': 35, 'num_neuronios_camada:2': 23, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.08492842676864432, 'taxa_de_dropout': 0.009425552879600344}. Best is trial 274 with value: 0.02556474693119526.
#  96%|█████████▌| 478/500 [1:02:38<02:29,  6.81s/it][I 2024-05-13 20:02:10,222] Trial 478 finished with value: 0.03128199651837349 and parameters: {'num_camadas': 4, 'num_neuronios_camada:0': 39, 'num_neuronios_camada:1': 33, 'num_neuronios_camada:2': 26, 'num_neuronios_camada:3': 36, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.07351332315323374, 'taxa_de_dropout': 0.016226893245705358}. Best is trial 274 with value: 0.02556474693119526.
#  96%|█████████▌| 479/500 [1:02:50<02:56,  8.43s/it][I 2024-05-13 20:02:14,821] Trial 479 finished with value: 0.06836938858032227 and parameters: {'num_camadas': 3, 'num_neuronios_camada:0': 28, 'num_neuronios_camada:1': 32, 'num_neuronios_camada:2': 25, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.08545396317057356, 'taxa_de_dropout': 0.44083188811333635}. Best is trial 274 with value: 0.02556474693119526.
#  96%|█████████▌| 480/500 [1:02:55<02:25,  7.28s/it][I 2024-05-13 20:02:30,645] Trial 480 finished with value: 0.04088849201798439 and parameters: {'num_camadas': 6, 'num_neuronios_camada:0': 36, 'num_neuronios_camada:1': 4, 'num_neuronios_camada:2': 27, 'num_neuronios_camada:3': 47, 'num_neuronios_camada:4': 37, 'num_neuronios_camada:5': 32, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.06292638464831214, 'taxa_de_dropout': 0.030292682136421223}. Best is trial 274 with value: 0.02556474693119526.
#  96%|█████████▌| 481/500 [1:03:11<03:06,  9.84s/it][I 2024-05-13 20:02:40,720] Trial 481 finished with value: 0.0257243849337101 and parameters: {'num_camadas': 4, 'num_neuronios_camada:0': 25, 'num_neuronios_camada:1': 28, 'num_neuronios_camada:2': 22, 'num_neuronios_camada:3': 38, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.09985245345824934, 'taxa_de_dropout': 0.008526836477965384}. Best is trial 274 with value: 0.02556474693119526.
#  96%|█████████▋| 482/500 [1:03:21<02:58,  9.91s/it][I 2024-05-13 20:02:51,462] Trial 482 finished with value: 0.03164844214916229 and parameters: {'num_camadas': 4, 'num_neuronios_camada:0': 25, 'num_neuronios_camada:1': 26, 'num_neuronios_camada:2': 22, 'num_neuronios_camada:3': 35, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.0826828568323823, 'taxa_de_dropout': 0.02084619409658339}. Best is trial 274 with value: 0.02556474693119526.
#  97%|█████████▋| 483/500 [1:03:31<02:52, 10.16s/it][I 2024-05-13 20:03:08,300] Trial 483 finished with value: 0.10496373474597931 and parameters: {'num_camadas': 8, 'num_neuronios_camada:0': 24, 'num_neuronios_camada:1': 28, 'num_neuronios_camada:2': 23, 'num_neuronios_camada:3': 38, 'num_neuronios_camada:4': 29, 'num_neuronios_camada:5': 20, 'num_neuronios_camada:6': 9, 'num_neuronios_camada:7': 9, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.022488237058485756, 'taxa_de_dropout': 0.036857064000070855}. Best is trial 274 with value: 0.02556474693119526.
#  97%|█████████▋| 484/500 [1:03:48<03:14, 12.16s/it][I 2024-05-13 20:03:19,218] Trial 484 finished with value: 0.029041340574622154 and parameters: {'num_camadas': 4, 'num_neuronios_camada:0': 26, 'num_neuronios_camada:1': 27, 'num_neuronios_camada:2': 21, 'num_neuronios_camada:3': 34, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.08597215475959015, 'taxa_de_dropout': 0.05206292471502572}. Best is trial 274 with value: 0.02556474693119526.
#  97%|█████████▋| 485/500 [1:03:59<02:56, 11.79s/it][I 2024-05-13 20:03:38,554] Trial 485 finished with value: 0.10496606677770615 and parameters: {'num_camadas': 7, 'num_neuronios_camada:0': 25, 'num_neuronios_camada:1': 28, 'num_neuronios_camada:2': 24, 'num_neuronios_camada:3': 42, 'num_neuronios_camada:4': 35, 'num_neuronios_camada:5': 24, 'num_neuronios_camada:6': 26, 'funcao_de_ativacao': 'Sigmoid', 'taxa_de_aprendizado': 0.08738608887427282, 'taxa_de_dropout': 0.010055464388927812}. Best is trial 274 with value: 0.02556474693119526.
#  97%|█████████▋| 486/500 [1:04:18<03:16, 14.05s/it][I 2024-05-13 20:03:48,804] Trial 486 finished with value: 0.026108836755156517 and parameters: {'num_camadas': 4, 'num_neuronios_camada:0': 26, 'num_neuronios_camada:1': 29, 'num_neuronios_camada:2': 21, 'num_neuronios_camada:3': 37, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.09852284312172276, 'taxa_de_dropout': 0.009980754474891605}. Best is trial 274 with value: 0.02556474693119526.
#  97%|█████████▋| 487/500 [1:04:29<02:47, 12.91s/it][I 2024-05-13 20:03:57,785] Trial 487 finished with value: 0.026044609025120735 and parameters: {'num_camadas': 4, 'num_neuronios_camada:0': 26, 'num_neuronios_camada:1': 28, 'num_neuronios_camada:2': 18, 'num_neuronios_camada:3': 37, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.09823061320884288, 'taxa_de_dropout': 0.00963980831605913}. Best is trial 274 with value: 0.02556474693119526.
#  98%|█████████▊| 488/500 [1:04:38<02:20, 11.73s/it][I 2024-05-13 20:04:08,187] Trial 488 finished with value: 0.029128413647413254 and parameters: {'num_camadas': 4, 'num_neuronios_camada:0': 26, 'num_neuronios_camada:1': 27, 'num_neuronios_camada:2': 17, 'num_neuronios_camada:3': 39, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.09904069702061125, 'taxa_de_dropout': 0.02760171988873851}. Best is trial 274 with value: 0.02556474693119526.
#  98%|█████████▊| 489/500 [1:04:48<02:04, 11.33s/it][I 2024-05-13 20:04:17,670] Trial 489 finished with value: 0.03907482326030731 and parameters: {'num_camadas': 5, 'num_neuronios_camada:0': 24, 'num_neuronios_camada:1': 28, 'num_neuronios_camada:2': 18, 'num_neuronios_camada:3': 36, 'num_neuronios_camada:4': 14, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.07381862407723842, 'taxa_de_dropout': 0.015573875526182977}. Best is trial 274 with value: 0.02556474693119526.
#  98%|█████████▊| 490/500 [1:04:58<01:47, 10.78s/it][I 2024-05-13 20:04:27,385] Trial 490 finished with value: 0.14423376321792603 and parameters: {'num_camadas': 4, 'num_neuronios_camada:0': 25, 'num_neuronios_camada:1': 29, 'num_neuronios_camada:2': 20, 'num_neuronios_camada:3': 37, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 1.1447230024376658e-05, 'taxa_de_dropout': 0.022465641551918738}. Best is trial 274 with value: 0.02556474693119526.
#  98%|█████████▊| 491/500 [1:05:07<01:34, 10.46s/it][I 2024-05-13 20:04:36,524] Trial 491 finished with value: 0.029238197952508926 and parameters: {'num_camadas': 4, 'num_neuronios_camada:0': 25, 'num_neuronios_camada:1': 28, 'num_neuronios_camada:2': 19, 'num_neuronios_camada:3': 35, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.09914305848344514, 'taxa_de_dropout': 0.008036100155284458}. Best is trial 274 with value: 0.02556474693119526.
#  98%|█████████▊| 492/500 [1:05:16<01:20, 10.06s/it][I 2024-05-13 20:04:45,225] Trial 492 finished with value: 0.04258035868406296 and parameters: {'num_camadas': 5, 'num_neuronios_camada:0': 26, 'num_neuronios_camada:1': 28, 'num_neuronios_camada:2': 16, 'num_neuronios_camada:3': 40, 'num_neuronios_camada:4': 4, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.09913041741727531, 'taxa_de_dropout': 0.031893738337219264}. Best is trial 274 with value: 0.02556474693119526.
#  99%|█████████▊| 493/500 [1:05:25<01:07,  9.65s/it][I 2024-05-13 20:04:55,236] Trial 493 finished with value: 0.03274140879511833 and parameters: {'num_camadas': 4, 'num_neuronios_camada:0': 27, 'num_neuronios_camada:1': 25, 'num_neuronios_camada:2': 18, 'num_neuronios_camada:3': 31, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.07238406869084077, 'taxa_de_dropout': 0.01720984724044942}. Best is trial 274 with value: 0.02556474693119526.
#  99%|█████████▉| 494/500 [1:05:35<00:58,  9.76s/it][I 2024-05-13 20:05:02,981] Trial 494 finished with value: 0.04188057780265808 and parameters: {'num_camadas': 4, 'num_neuronios_camada:0': 3, 'num_neuronios_camada:1': 26, 'num_neuronios_camada:2': 19, 'num_neuronios_camada:3': 33, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.05530032585774311, 'taxa_de_dropout': 0.045163309657865275}. Best is trial 274 with value: 0.02556474693119526.
#  99%|█████████▉| 495/500 [1:05:43<00:45,  9.16s/it][I 2024-05-13 20:05:11,597] Trial 495 finished with value: 0.09536731988191605 and parameters: {'num_camadas': 4, 'num_neuronios_camada:0': 24, 'num_neuronios_camada:1': 29, 'num_neuronios_camada:2': 17, 'num_neuronios_camada:3': 38, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.004498751307852425, 'taxa_de_dropout': 0.008297689678368919}. Best is trial 274 with value: 0.02556474693119526.
#  99%|█████████▉| 496/500 [1:05:51<00:35,  8.99s/it][I 2024-05-13 20:05:20,802] Trial 496 finished with value: 0.02745090052485466 and parameters: {'num_camadas': 4, 'num_neuronios_camada:0': 26, 'num_neuronios_camada:1': 27, 'num_neuronios_camada:2': 14, 'num_neuronios_camada:3': 34, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.08460800437319752, 'taxa_de_dropout': 0.00825891739544331}. Best is trial 274 with value: 0.02556474693119526.
#  99%|█████████▉| 497/500 [1:06:01<00:27,  9.06s/it][I 2024-05-13 20:05:32,322] Trial 497 finished with value: 0.04257605969905853 and parameters: {'num_camadas': 5, 'num_neuronios_camada:0': 27, 'num_neuronios_camada:1': 29, 'num_neuronios_camada:2': 22, 'num_neuronios_camada:3': 30, 'num_neuronios_camada:4': 7, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.0730363257956424, 'taxa_de_dropout': 0.022688632374993797}. Best is trial 274 with value: 0.02556474693119526.
# 100%|█████████▉| 498/500 [1:06:12<00:19,  9.80s/it][I 2024-05-13 20:05:42,069] Trial 498 finished with value: 0.03294526785612106 and parameters: {'num_camadas': 4, 'num_neuronios_camada:0': 26, 'num_neuronios_camada:1': 30, 'num_neuronios_camada:2': 20, 'num_neuronios_camada:3': 37, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.06440747294853913, 'taxa_de_dropout': 0.01525658811606025}. Best is trial 274 with value: 0.02556474693119526.
# 100%|█████████▉| 499/500 [1:06:22<00:09,  9.78s/it][I 2024-05-13 20:05:53,881] Trial 499 finished with value: 0.027523720636963844 and parameters: {'num_camadas': 4, 'num_neuronios_camada:0': 25, 'num_neuronios_camada:1': 27, 'num_neuronios_camada:2': 22, 'num_neuronios_camada:3': 39, 'funcao_de_ativacao': 'ReLU', 'taxa_de_aprendizado': 0.08333032839595853, 'taxa_de_dropout': 0.008874495275174999}. Best is trial 274 with value: 0.02556474693119526.
# 100%|██████████| 500/500 [1:06:34<00:00,  7.99s/it]

# %% [markdown]
# #### Definindo os hiperparametros:

# %%
EPOCAS = 2000
NUM_DADOS_DE_ENTRADA = 20
ESTRUTURA_OCULTA = neuronios_camada
NUM_DADOS_DE_SAIDA = 1
FUNCAO_ATIVACAO = parametros['funcao_de_ativacao']
TAXA_DE_APRENDIZADO = parametros['taxa_de_aprendizado']
TAXA_DE_DROPOUT = parametros['taxa_de_dropout']

print('Hiperparametros da Rede:')
print(f'Numero de Dados de Entrada:{NUM_DADOS_DE_ENTRADA}')
print(f'Numero de Neuronios e Camadas: {ESTRUTURA_OCULTA}')
print(f'Função de ativação escolhida: {FUNCAO_ATIVACAO}')
print(f'Numero de Dados de Saída: {NUM_DADOS_DE_SAIDA}')
print(f'Taxa de apredizado do modelo: {TAXA_DE_APRENDIZADO}')
print(f'Taxa de Dropout do modelo: {TAXA_DE_DROPOUT}')
# Out:
# Hiperparametros da Rede:
# Numero de Dados de Entrada:20
# Numero de Neuronios e Camadas: [23, 30, 25, 31]
# Função de ativação escolhida: ReLU
# Numero de Dados de Saída: 1
# Taxa de apredizado do modelo: 0.09966372836400053
# Taxa de Dropout do modelo: 0.0004178587370442764

# %% [markdown]
# #### Treinando a rede com os melhores hiperparametros:

# %%
# Criando uma instância do modelo com os melhores hiperparâmetros
modelo = view_predictor_MLP(NUM_DADOS_DE_ENTRADA, ESTRUTURA_OCULTA, NUM_DADOS_DE_SAIDA, FUNCAO_ATIVACAO, TAXA_DE_APRENDIZADO, TAXA_DE_DROPOUT)

# Treinando o modelo
modelo.treinamento(X_treino, y_treino, EPOCAS)

# %% [markdown]
# ### Testando a Rede Neural:

# %% [markdown]
# #### Prevendo os targets do X de tete:

# %%
# Realizando a previsão do numero de vizualizações com base no dataset X_teste
y_predito = modelo.predicao(X_teste)

# %% [markdown]
# #### Calculando a eficiencia da Previsão:

# %%
# Calculando a eficiência da Rede Neural, utilizando o Erro quadrático médio.
MSE = mean_squared_error(y_teste, y_predito)

#  Calculando a eficiência da Rede Neural, utilizando a Raiz do Erro quadrático médio.
RMSE = np.sqrt(MSE)

print(f' A rede possúi um MSE: {MSE} V² e um RMSE: {RMSE} V')
# Out:
#  A rede possúi um MSE: 0.02313041500747204 V² e um RMSE: 0.15208686888217926 V

# %% [markdown]
# # Referência:

# %% [markdown]
# [1] Video aulas e notebooks disponibilizados pelo professor Daniel Roberto Cassar.
